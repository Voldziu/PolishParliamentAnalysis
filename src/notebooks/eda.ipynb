# %% [markdown]
# # Imports

# %%
import pandas as pd
from pathlib import Path
import numpy as np
import networkx as nx
import seaborn as sns
import matplotlib.pyplot as plt

from utils.config import OUT_DIR, CLUBS_ORDERED
from utils.graph.layout import plot_graph_by_club
SRC_ROOT = Path('').resolve().parents[1]
PARQUET_OUT_DIR = SRC_ROOT / OUT_DIR

# %% [markdown]
# # Dataframes loading

# %% [markdown]
# ## Proceedings

# %%
df_proceedings = pd.read_parquet(PARQUET_OUT_DIR / 'proceedings.parquet')

# %%
df_proceedings[df_proceedings['sitting']>0]
# Out:
#     sitting                                              title
# 0         1  1. Posiedzenie Sejmu RP w dniach 13, 14, 21, 2...
# 1         2  2. Posiedzenie Sejmu RP w dniach 16 i 17 stycz...
# 2         3  3. Posiedzenie Sejmu RP w dniu 18 stycznia 202...
# 3         4  4. Posiedzenie Sejmu RP w dniach 25 i 26 stycz...
# 4         5  5. Posiedzenie Sejmu RP w dniach 7, 8 i 9 lute...
# 5         6  6. Posiedzenie Sejmu RP w dniach 21 i 22 luteg...
# 6         7  7. Posiedzenie Sejmu RP w dniach 6, 7 i 8 marc...
# 7         8  8. Posiedzenie Sejmu RP w dniach 20 i 21 marca...
# 8         9  9. Posiedzenie Sejmu RP w dniach 10, 11 i 12 k...
# 9        10  10. Posiedzenie Sejmu RP w dniach 24, 25 i 26 ...
# 10       11  11. Posiedzenie Sejmu RP w dniach 8, 9 i 15 ma...
# 11       12  12. Posiedzenie Sejmu RP w dniach 22 i 23 maja...
# 12       13  13. Posiedzenie Sejmu RP w dniach 12, 13 i 14 ...
# 13       14  14. Posiedzenie Sejmu RP w dniach 26, 27 i 28 ...
# 14       15  15. Posiedzenie Sejmu RP w dniach 11 i 12 lipc...
# 15       16  16. Posiedzenie Sejmu RP w dniach 23, 24, 25 i...
# 16       17  17. Posiedzenie Sejmu RP w dniach 11, 12 i 13 ...
# 17       18  18. Posiedzenie Sejmu RP w dniach 25, 26 i 27 ...
# 18       19  19. Posiedzenie Sejmu RP w dniach 9, 10 i 11 p...
# 19       20  20. Posiedzenie Sejmu RP w dniach 16, 17 i 18 ...
# 20       21  21. Posiedzenie Sejmu RP w dniach 6, 7 i 8 lis...
# 21       22  22. Posiedzenie Sejmu RP w dniach 19, 20, 21, ...
# 22       23  23. Posiedzenie Sejmu RP w dniach 4 i 5 grudni...
# 23       24  24. Posiedzenie Sejmu RP w dniu 6 grudnia 2024 r.
# 24       25  25. Posiedzenie Sejmu RP w dniach 18, 19 i 20 ...
# 25       26  26. Posiedzenie Sejmu RP w dniach 8, 9 i 10 st...
# 26       27  27. Posiedzenie Sejmu RP w dniach 22, 23 i 24 ...
# 27       28  28. Posiedzenie Sejmu RP w dniach 5 i 6 lutego...
# 28       29  29. Posiedzenie Sejmu RP w dniach 20 i 21 lute...
# 29       30  30. Posiedzenie Sejmu RP w dniach 5, 6 i 7 mar...
# 30       31  31. Posiedzenie Sejmu RP w dniach 19 i 20 marc...
# 31       32  32. Posiedzenie Sejmu RP w dniach 2, 3 i 4 kwi...
# 32       33  33. Posiedzenie Sejmu RP w dniach 23 i 24 kwie...
# 33       34  34. Posiedzenie Sejmu RP w dniach 7, 8 i 9 maj...
# 34       35  35. Posiedzenie Sejmu RP w dniach 20 i 21 maja...
# 35       36  36. Posiedzenie Sejmu RP w dniach 3, 4 i 11 cz...
# 36       37  37. Posiedzenie Sejmu RP w dniach 24, 25 i 26 ...
# 37       38  38. Posiedzenie Sejmu RP w dniach 8, 9 i 10 li...
# 38       39  39. Posiedzenie Sejmu RP w dniach 22, 23, 24 i...
# 39       40  40. Posiedzenie Sejmu RP w dniach 9, 10, 11 i ...
# 40       41  41. Posiedzenie Sejmu RP w dniach 24, 25 i 26 ...
# 41       42  42. Posiedzenie Sejmu RP w dniach 7, 8 i 9 paź...
# 42       43  43. Posiedzenie Sejmu RP w dniach 15, 16 i 17 ...
# 43       44  44. Posiedzenie Sejmu RP w dniach 5, 6 i 7 lis...
# 44       45  45. Posiedzenie Sejmu RP w dniach 18, 19, 20 i...
# 45       46  46. Posiedzenie Sejmu RP w dniach 3, 4 i 5 gru...
# 46       47  47. Posiedzenie Sejmu RP w dniu 5 grudnia 2025 r.
# 47       48  48. Posiedzenie Sejmu RP w dniach 17, 18 i 19 ...
# 48       49  49. Posiedzenie Sejmu RP w dniach 8 i 9 styczn...
# 49       50  50. Posiedzenie Sejmu RP w dniach 21, 22 i 23 ...
# 50       51  51. Posiedzenie Sejmu RP w dniach 10, 11, 12 i...
# 51       52  52. Posiedzenie Sejmu RP w dniach 25, 26 i 27 ...
# 52       53  53. Posiedzenie Sejmu RP w dniach 11, 12 i 13 ...
# 53       54  54. Posiedzenie Sejmu RP w dniach 25, 26 i 27 ...
# 54       55  55. Posiedzenie Sejmu RP w dniach 14, 15, 16 i...
# 55       56  56. Posiedzenie Sejmu RP w dniach 28, 29 i 30 ...

# %% [markdown]
# ## Voting

# %%
df_votings = pd.read_parquet(PARQUET_OUT_DIR / 'votings.parquet')

# %%
len(df_votings)
# Out:
# 3828

# %%
df_votings.iloc[2,4]

# %% [markdown]
# ## Votes

# %%
df_votes = pd.read_parquet(PARQUET_OUT_DIR / 'votes.parquet')

# %%
df_votes.head()

# %% [markdown]
# ## Members

# %%
df_members = pd.read_parquet(PARQUET_OUT_DIR / 'members.parquet')

# %%
df_members.head()
# Out:
#    MP club firstName                lastName
# 0   1  PiS   Andrzej                Adamczyk
# 1   2   KO     Piotr               Adamowicz
# 2   3  PiS      Adam          Andruszkiewicz
# 3   4  PiS  Waldemar                  Andzel
# 4   5  PiS    Dorota  Arciszewska-Mielewczyk

# %%
df_members[df_members['lastName']=='Müller']
# Out:
#       MP club firstName lastName
# 254  255  PiS     Piotr   Müller

# %%
df_members.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MP         498 non-null    int64
#  1   club       498 non-null    str
#  2   firstName  498 non-null    str
#  3   lastName   498 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 25.0 KB

# %% [markdown]
# # Graph creation

# %% [markdown]
# ## Sanity check

# %%
required_votes_cols = {"sitting", "votingNumber", "MP", "vote"}
required_votings_cols = {"sitting", "votingNumber", "yes", "totalVoted"}
required_members_cols = {"MP", "club"}

missing_votes = required_votes_cols - set(df_votes.columns)
missing_votings = required_votings_cols - set(df_votings.columns)
missing_members = required_members_cols - set(df_members.columns)

if missing_votes or missing_votings or missing_members:
    raise ValueError(
        "Missing required columns: "
        f"votes={sorted(missing_votes)}, "
        f"votings={sorted(missing_votings)}, "
        f"members={sorted(missing_members)}"
    )

# %% [markdown]
# ## Polarity

# %%
polarity_per_voting = df_votings[["sitting", "votingNumber", "yes", "totalVoted"]].copy()
polarity_per_voting = polarity_per_voting[polarity_per_voting["totalVoted"] > 0].copy()
p_yes = polarity_per_voting["yes"] / polarity_per_voting["totalVoted"]
polarity_per_voting["polarity"] = 1 - 2 * (p_yes - 0.5).abs()
polarity_per_voting.head()

# %% [markdown]
# ## Votes with polarity df

# %%
votes_with_polarity = df_votes[["sitting", "votingNumber", "MP", "vote"]].merge(
    polarity_per_voting[["sitting", "votingNumber", "polarity"]],
    on=["sitting", "votingNumber"],
    how="inner",
)
votes_with_polarity.head()

# %% [markdown]
# ## Merge with itself

# %%
pairs = votes_with_polarity.merge(
    votes_with_polarity,
    on=["sitting", "votingNumber"],
    suffixes=("_i", "_j"),
)
pairs = pairs[pairs["MP_i"] < pairs["MP_j"]].copy()
pairs.head()

# %% [markdown]
# ## Calculate polarity-weighted agreement score

# %% [markdown]
# Let:
# - $V$ be the set of all votings,
# - $M$ be the set of all members,
# - $x_{i,v} \in \{\mathrm{YES}, \mathrm{NO}, \mathrm{ABSTAIN}\}$ be the vote cast by member $i \in M$ in voting $v \in V$.
#
# For each voting $v$, define:
#
# $$
# p_v = \frac{\mathrm{yes}_v}{\mathrm{totalVoted}_v},
# \qquad
# w_v = 1 - 2\left|p_v - \frac{1}{2}\right|.
# $$
#
# For each pair $(i,j)$ with $i < j$, over all votings where both members participated ($V_{ij}$):
#
# $$
# \mathrm{denom}_{ij} = \sum_{v \in V_{ij}} w_v,
# $$
#
# $$
# \mathrm{score}_{ij} = \sum_{v \in V_{ij}} w_v \, \mathbf{1}\!\left(x_{i,v} = x_{j,v}\right),
# $$
#
# where $\mathbf{1}(\cdot)$ is the indicator function.
#
# Finally, the edge weight is:
#
# $$
# \mathrm{weight}_{ij} =
# \begin{cases}
# \dfrac{\mathrm{score}_{ij}}{\mathrm{denom}_{ij}}, & \text{if } \mathrm{denom}_{ij} > 0, \\
# \text{no edge}, & \text{if } \mathrm{denom}_{ij} = 0.
# \end{cases}
# $$
#
# This matches the implementation: `denom_w = polarity`, `score_w = polarity * (vote_i == vote_j)`, then aggregation by member pair.

# %%
pairs["denom_w"] = pairs["polarity_i"]
pairs["score_w"] = pairs["denom_w"] * pairs["vote_i"].eq(pairs["vote_j"]).astype(float)
pairs

# %%
edge_stats = pairs.groupby(["MP_i", "MP_j"], as_index=False).agg(
    score=("score_w", "sum"),
    denom=("denom_w", "sum"),
    
) 
edge_stats = edge_stats[edge_stats["denom"] > 0].copy()
edge_stats.head()

# %% [markdown]
# ## Calculate the weight

# %%
edge_stats = edge_stats[edge_stats["denom"] > 0].copy()
edge_stats["weight"] = edge_stats["score"] / edge_stats["denom"]
edge_stats

# %% [markdown]
# ## Add members' clubs to the graph

# %%
members_nodes = df_members[["MP", "club"]].drop_duplicates(subset=["MP"]).copy()

# %%
G = nx.Graph()
for row in members_nodes.itertuples(index=False):
    G.add_node(int(row.MP), club=row.club)

# %%
for row in edge_stats.itertuples(index=False):
    G.add_edge(
        int(row.MP_i),
        int(row.MP_j),
        weight=float(row.weight)
    )

graph_stats = {
    "nodes": G.number_of_nodes(),
    "edges": G.number_of_edges(),
    "weight_min": float(edge_stats["weight"].min()) if not edge_stats.empty else None,
    "weight_mean": float(edge_stats["weight"].mean()) if not edge_stats.empty else None,
    "weight_max": float(edge_stats["weight"].max()) if not edge_stats.empty else None,
}

graph_stats

# %% [markdown]
# # Visualizing the weights

# %%
plt.figure(figsize=(10, 5))
sns.histplot(edge_stats["weight"], bins=30, kde=True)
plt.title("Histogram of Edge Weights")
plt.xlabel("Weight")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sparsing the graph with threshold

# %%
THRESHOLD_DOWN = 0.2
THRESHOLD_UP = 1.0

sparse_G = nx.Graph(
    (u, v, d) for u, v, d in G.edges(data=True) if THRESHOLD_DOWN <= d["weight"] <= THRESHOLD_UP
)
for node in G.nodes:
    if node in G.nodes:
        nx.set_node_attributes(sparse_G, {node: G.nodes[node]})

# %%
plot_graph_by_club(
    sparse_G,
    clubs_ordered=CLUBS_ORDERED,
    node_size=240,
    jitter=0.08,
    
    seed=7,
    show_node_ids=True,
    node_id_font_size=8,
    title=f"MP Voting Similarity Graph (edges with weight in [{THRESHOLD_DOWN}, {THRESHOLD_UP}])",
)

# %%
plt.figure(figsize=(10, 5))
sns.histplot(edge_stats["weight"], bins=30, kde=True)
plt.title("Histogram of Edge Weights")
plt.xlabel("Weight")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
df_members.loc[df_members["MP"] == 309]
